# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import csv
import pandas as pd
from time import sleep
import time

# %%
br = webdriver.Edge()

fields = ['Symbol',	'Name',	'Price (Intraday)',
          	'Change',	'% Change',	'Volume',
            'Avg Vol (3 month)',  'Market Cap',
            'PE Ratio (TTM)',	'52 Week Range']

df = []
offset = 0
while True:
    try:
        br.get(f'https://finance.yahoo.com/screener/unsaved/344d9065-e9e0-4f4a-8284-f97aeb6506d2?offset={offset}&count=100')
    except:
         break
    sleep(1)
    
    try:
        tb = br.find_element(By.XPATH ,'.//*[@id="scr-res-table"]/div[1]/table')
    except:
        break
    sleep(1)
    
    rows = tb.find_elements(By.XPATH, ".//tbody/tr")

    for row in range(1,len(rows)+1):
            temp = {}
            for col in range(1,11):
                value = tb.find_element(By.XPATH, f".//tbody/tr[{row}]/td[{col}]").text
                temp[fields[col-1]] = value

            df.append(temp)
    offset += 100
br.close()

# %%
pd.DataFrame(df)
# Out:
#      Symbol                                        Name Price (Intraday)  \
# 0    5128.T                        WOW WORLD GROUP Inc.         1,502.00
# 1    7203.T                    Toyota Motor Corporation         2,022.00
# 2    6861.T                         Keyence Corporation        69,400.00
# 3    6758.T                      Sony Group Corporation        13,605.00
# 4    9432.T  Nippon Telegraph and Telephone Corporation         4,107.00
# ..      ...                                         ...              ...
# 195  2702.T   McDonald's Holdings Company (Japan), Ltd.         5,690.00
# 196  7747.T                      Asahi Intecc Co., Ltd.         2,771.50
# 197  5332.T                                   Toto Ltd.         4,425.00
# 198  6465.T                       Hoshizaki Corporation         5,174.00
# 199  3635.T               Koei Tecmo Holdings Co., Ltd.         2,373.50
#
#         Change % Change   Volume Avg Vol (3 month) Market Cap PE Ratio (TTM)  \
# ...

# %%
# filename = "ListingCompany.csv"

# with open(filename, 'w', encoding= 'utf-8', newline= '') as csvfile:
#     writer = csv.DictWriter(csvfile, fields,lineterminator = '\r')
#     writer.writeheader()
#     writer.writerows(df)
